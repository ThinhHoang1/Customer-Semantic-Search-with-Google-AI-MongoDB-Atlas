# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv
import os
# --- 1. Load Environment Variables ---
load_dotenv() # This line loads variables from your .env file
uri = os.getenv("MONGO_URI")

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# %pip install "pymongo[srv]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pymongo 4.13.0 does not provide the extra 'srv'

# %%
import pandas as pd

# %%
df = pd.read_csv("Customers.csv")

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
list_of_dict = df.to_dict(orient='records')

# %%
list_of_dict
# Out:
# [{'CustomerID': 1,
#   'Gender': 'Male',
#   'Age': 19,
#   'Annual Income ($)': 15000,
#   'Spending Score (1-100)': 39,
#   'Profession': 'Healthcare',
#   'Work Experience': 1,
#   'Family Size': 4},
#  {'CustomerID': 2,
#   'Gender': 'Male',
#   'Age': 21,
#   'Annual Income ($)': 35000,
#   'Spending Score (1-100)': 81,
#   'Profession': 'Engineer',
#   'Work Experience': 3,
#   'Family Size': 3},
#  {'CustomerID': 3,
#   'Gender': 'Female',
#   'Age': 20,
#   'Annual Income ($)': 86000,
#   'Spending Score (1-100)': 6,
#   'Profession': 'Engineer',
#   'Work Experience': 1,
#   'Family Size': 1},
#  {'CustomerID': 4,
#   'Gender': 'Female',
#   'Age': 23,
#   'Annual Income ($)': 59000,
#   'Spending Score (1-100)': 77,
#   'Profession': 'Lawyer',
#   'Work Experience': 0,
#   'Family Size': 2},
#  {'CustomerID': 5,
#   'Gender': 'Female',
#   'Age': 31,
#   'Annual Income ($)': 38000,
#   'Spending Score (1-100)': 40,
#   'Profession': 'Entertainment',
# ...

# %%
db = client["customer"]

# %%
db.list_collection_names()
# Out:
# ['customer_behavior']

# %%
collection = db["customer_behavior"]

# Insert data into the collection (if needed)
if list_of_dict:
    collection.insert_many(list_of_dict)
    print("Data inserted successfully into 'customer_behavior' collection.")
else:
    print("No data to insert.")
# Out:
# Data inserted successfully into 'customer_behavior' collection.
